# %%
print("hello world!!")
# Out:
# hello world!!

# %%
"AIzaSyAO8nHHnXz_nS4aUZsMKKdZnhHQp9J1hgQ"
# Out:
# 'AIzaSyAO8nHHnXz_nS4aUZsMKKdZnhHQp9J1hgQ'

# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %%
#API key connection

def Api_connect():
    Api_Id="AIzaSyAO8nHHnXz_nS4aUZsMKKdZnhHQp9J1hgQ"

    api_service_name="youtube"
    api_version="v3"

    youtube=build(api_service_name,api_version,developerKey=Api_Id)

    return youtube

youtube=Api_connect()

# %%
#Get channels information

def get_channel_info(channel_id):
    request=youtube.channels().list(
                    part="snippet,ContentDetails,statistics",
                    id=channel_id
    )
    response=request.execute()
    
    for i in response["items"]:
        data=dict(Channel_Name=i["snippet"]["title"],
                Channel_Id=i["id"],
                Subscribers=i["statistics"]["subscriberCount"],
                Views=i["statistics"]["viewCount"],
                Total_Videos=i["statistics"]["videoCount"],
                Channel_Description=i["snippet"]["description"],
                Playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"])
    return data

# %%
channel_details=get_channel_info("UCuI5XcJYynHa5k_lqDzAgwQ")

# %%
channel_details
# Out:
# {'Channel_Name': 'Data Science Tamil',
#  'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#  'Subscribers': '1190',
#  'Views': '184277',
#  'Total_Videos': '71',
#  'Channel_Description': 'Welcome to the Data Science Tamil Channel! Here, we delve into the captivating realm of data science, machine learning, and artificial intelligence. 🌟 Whether you\'re a seasoned data enthusiast, a curious learner, or just someone intrigued by the magic of data, this channel is for you! 🎉\n\nJoin us as we unravel the mysteries of data analysis, predictive modeling, and data visualization. From beginner-friendly tutorials to advanced discussions, we\'ve got you covered. 📈 Discover how data science is reshaping industries, solving complex problems, and driving innovation. 💡\n\nStay tuned for regular updates, insightful discussions, and community interactions. Subscribe now and embark on an enlightening journey through the fascinating world of data science! 🌐 Let\'s unlock the power of data together! 💪\n\n"To all my subscribers: I want to reassure you that if there are any mistakes in my videos, I\'ll annotate and guide for clarity. Your support fuels our content. Thank you!"\n',
#  'Playlist_Id': 'UUuI5XcJYynHa5k_lqDzAgwQ'}

# %%
channel_details["Total_Videos"]
# Out:
# '71'

# %%
#get video ids

def get_videos_ids(channel_id):
    video_ids=[]
    response=youtube.channels().list(id="UCuI5XcJYynHa5k_lqDzAgwQ",
                                    part="contentDetails").execute()

    Playlist_Id=response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    next_page_token=None

    while True:
        response1=youtube.playlistItems().list(
                                            part='snippet',
                                            playlistId=Playlist_Id,
                                            maxResults=50,
                                            pageToken=next_page_token).execute()
        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][0]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get('nextPageToken')
        
        if next_page_token is None:
            break
    return video_ids

# %%
Video_Ids=get_videos_ids('UCuI5XcJYynHa5k_lqDzAgwQ')

# %%
Video_Ids
# Out:
# ['JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'JdyZ-ek67bI',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c',
#  'Bqgjq6NGL4c']

# %%
len(Video_Ids)
# Out:
# 71

# %%
#Get Video information
def get_video_info(video_ids):
    video_data=[]
    for video_id in video_ids:
        request=youtube.videos().list(
            part="snippet,ContentDetails,statistics",
            id=video_id
        )
        response=request.execute()

        for item in response["items"]:
            data=dict(Channel_Name=item["snippet"]["channelTitle"],
                    Channel_Id=item["snippet"]["channelId"],
                    Video_Id=item["id"],
                    Title=item["snippet"]["title"],
                    Tags=item["snippet"]["tags"],
                    Thumbnail=item["snippet"]["thumbnails"]["default"]["url"],
                    Description=item["snippet"]["description"],
                    Published_Date=item["snippet"]["publishedAt"],
                    Duration=item["contentDetails"]["duration"],
                    Views=item["statistics"]["viewCount"],
                    Likes=item["statistics"]["likeCount"],
                    Comments=item["statistics"]["commentCount"],
                    Favorite_Count=item["statistics"]["favoriteCount"],
                    Definition=item["contentDetails"]["definition"],
                    Caption_Status=item["contentDetails"]["caption"]
                    )
            video_data.append(data)

    return video_data

# %%
video_details=get_video_info(Video_Ids)

# %%
video_details
# Out:
# [{'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
#   'Description': "Welcome to BizCardX! 🚀 In this comprehensive tutorial, we'll guide you through the development of a robust Streamlit application designed to streamline the process of extracting essential information from business cards using Optical Character Recognition (OCR).\n\nImage Location: https://drive.google.com/drive/folders/1FhLOdeeQ4Bfz48JAfHrU_VXvNTRgajhp?usp=sharing\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n🔍 Dive into the following steps:\n\nInstallation: Set up your environment with Python, Streamlit, easyOCR, and a database system like SQLite or MySQL.\nUser Interface Design: Craft an intuitive UI featuring file uploaders, buttons, and text boxes for seamless interaction.\n\nOCR Implementation: Harness the power of easyOCR to accurately extract relevant information from uploaded business card images.\nData Display: Present the extracted data neatly within the Streamlit GUI using tables, text boxes, and labels for clarity.\n\nDatabase Integration: Incorporate a database system to store both the extracted information and uploaded business card images, ensuring efficient data management.\nTesting & Optimization: Rigorously test the application's functionality and continuously enhance it for an optimized user experience.\n\n📈 Witness the transformation with BizCardX! Revolutionize the way business card data is handled with our simple yet powerful interface, scalable architecture, and robust database integration. Whether you're a business professional or an individual, BizCardX is your go-to tool for efficient contact management.\n\n#BizCardX #OCR #Streamlit #DataExtraction #DatabaseManagement #PythonTutorial #OpenAI #TechTutorial #DataProcessing #ImageProcessing #BusinessCards #DataManagement #SQLite #MySQL #GUI #UserInterface #SoftwareDevelopment #OpticalCharacterRecognition #StreamlitTutorial #databaseintegration \n\nDon't miss out on this exciting journey! Like, share, and subscribe for more cutting-edge tutorials on Python, Streamlit, OCR, and beyond. Let's unlock the full potential of BizCardX together! 💼💡",
#   'Published_Date': '2024-03-27T18:30:06Z',
#   'Duration': 'PT31M18S',
#   'Views': '922',
#   'Likes': '17',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Title': 'Delete the Data from Table |BizCardX:Extracting Business Card Data with OCR|OCR,Streamlit,SQL|Part10',
#   'Tags': ['BizCardX',
#    'OCR',
#    'Streamlit in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'BizCardX: Extracting Business Card Data with OCR',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data science full course in tamil',
#    'Streamlit',
#    'Python Tutorial',
#    'Image Processing',
#    'Business Cards',
#    'SQLite',
#    'MySQL',
#    'GUI',
#    'User Interface',
#    'Optical Character Recognition',
#    'Streamlit Tutorial',
#    'Data Processing',
#    'delete the data from table',
#    'part10'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdyZ-ek67bI/default.jpg',
# ...
#   'Title': 'PhonePe Pulse Data Visualization and Exploration|Convert to Dataframe4|part 1.4|Streamlit and Plotly',
#   'Tags': ['PhonePe',
#    'DataVisualization in tamil',
#    'DataExploration in tamil',
#    'Streamlit in tamil',
#    'Plotly in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'phonepe pulse data visualization and exploration project tamil',
#    'phonepe pulse data visualization github in tamil',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'how to create a dataframe tamil',
#    'plotly tamil',
#    'streamlit tamil',
#    'phonepe project explanation tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Bqgjq6NGL4c/default.jpg',
#   'Description': "PhonePe has emerged as a leader among digital payment platforms, catering to millions of users for their daily transactions. Renowned for its user-friendly interface, rapid and secure payment processing, and innovative features, PhonePe has garnered accolades and recognition within the industry.\n\nIn the PhonePe Pulse Data Visualization and Exploration project, we embark on a mission to extract valuable insights from PhonePe's GitHub repository. Our goal is to meticulously process this data and present it through an interactive dashboard that captivates with its visual appeal. This endeavor is made possible by leveraging the power of Python, Streamlit, and Plotly.\n\nPhonepe Pulse Data Visualization and Exploration:\nA User-Friendly Tool Using Streamlit and Plotly\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n#streamlit #datavisualization #python\n🔗 Join us on this exciting data-driven journey as we explore the world of YouTube data and unlock the potential of data science!\n\nSubscribe to our channel for more insightful projects, tutorials, and data science content. Let's uncover the power of data together!",
#   'Published_Date': '2023-11-23T09:24:35Z',
#   'Duration': 'PT17M46S',
#   'Views': '2532',
#   'Likes': '52',
#   'Comments': '56',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Title': 'PhonePe Pulse Data Visualization and Exploration|Convert to Dataframe4|part 1.4|Streamlit and Plotly',
#   'Tags': ['PhonePe',
#    'DataVisualization in tamil',
#    'DataExploration in tamil',
#    'Streamlit in tamil',
#    'Plotly in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'phonepe pulse data visualization and exploration project tamil',
#    'phonepe pulse data visualization github in tamil',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'how to create a dataframe tamil',
#    'plotly tamil',
#    'streamlit tamil',
#    'phonepe project explanation tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Bqgjq6NGL4c/default.jpg',
#   'Description': "PhonePe has emerged as a leader among digital payment platforms, catering to millions of users for their daily transactions. Renowned for its user-friendly interface, rapid and secure payment processing, and innovative features, PhonePe has garnered accolades and recognition within the industry.\n\nIn the PhonePe Pulse Data Visualization and Exploration project, we embark on a mission to extract valuable insights from PhonePe's GitHub repository. Our goal is to meticulously process this data and present it through an interactive dashboard that captivates with its visual appeal. This endeavor is made possible by leveraging the power of Python, Streamlit, and Plotly.\n\nPhonepe Pulse Data Visualization and Exploration:\nA User-Friendly Tool Using Streamlit and Plotly\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n#streamlit #datavisualization #python\n🔗 Join us on this exciting data-driven journey as we explore the world of YouTube data and unlock the potential of data science!\n\nSubscribe to our channel for more insightful projects, tutorials, and data science content. Let's uncover the power of data together!",
#   'Published_Date': '2023-11-23T09:24:35Z',
#   'Duration': 'PT17M46S',
#   'Views': '2532',
#   'Likes': '52',
#   'Comments': '56',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Title': 'PhonePe Pulse Data Visualization and Exploration|Convert to Dataframe4|part 1.4|Streamlit and Plotly',
#   'Tags': ['PhonePe',
#    'DataVisualization in tamil',
#    'DataExploration in tamil',
#    'Streamlit in tamil',
#    'Plotly in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'phonepe pulse data visualization and exploration project tamil',
#    'phonepe pulse data visualization github in tamil',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'how to create a dataframe tamil',
#    'plotly tamil',
#    'streamlit tamil',
#    'phonepe project explanation tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Bqgjq6NGL4c/default.jpg',
#   'Description': "PhonePe has emerged as a leader among digital payment platforms, catering to millions of users for their daily transactions. Renowned for its user-friendly interface, rapid and secure payment processing, and innovative features, PhonePe has garnered accolades and recognition within the industry.\n\nIn the PhonePe Pulse Data Visualization and Exploration project, we embark on a mission to extract valuable insights from PhonePe's GitHub repository. Our goal is to meticulously process this data and present it through an interactive dashboard that captivates with its visual appeal. This endeavor is made possible by leveraging the power of Python, Streamlit, and Plotly.\n\nPhonepe Pulse Data Visualization and Exploration:\nA User-Friendly Tool Using Streamlit and Plotly\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n#streamlit #datavisualization #python\n🔗 Join us on this exciting data-driven journey as we explore the world of YouTube data and unlock the potential of data science!\n\nSubscribe to our channel for more insightful projects, tutorials, and data science content. Let's uncover the power of data together!",
#   'Published_Date': '2023-11-23T09:24:35Z',
#   'Duration': 'PT17M46S',
#   'Views': '2532',
#   'Likes': '52',
#   'Comments': '56',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Title': 'PhonePe Pulse Data Visualization and Exploration|Convert to Dataframe4|part 1.4|Streamlit and Plotly',
#   'Tags': ['PhonePe',
#    'DataVisualization in tamil',
#    'DataExploration in tamil',
#    'Streamlit in tamil',
#    'Plotly in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'phonepe pulse data visualization and exploration project tamil',
#    'phonepe pulse data visualization github in tamil',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'how to create a dataframe tamil',
#    'plotly tamil',
#    'streamlit tamil',
#    'phonepe project explanation tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Bqgjq6NGL4c/default.jpg',
#   'Description': "PhonePe has emerged as a leader among digital payment platforms, catering to millions of users for their daily transactions. Renowned for its user-friendly interface, rapid and secure payment processing, and innovative features, PhonePe has garnered accolades and recognition within the industry.\n\nIn the PhonePe Pulse Data Visualization and Exploration project, we embark on a mission to extract valuable insights from PhonePe's GitHub repository. Our goal is to meticulously process this data and present it through an interactive dashboard that captivates with its visual appeal. This endeavor is made possible by leveraging the power of Python, Streamlit, and Plotly.\n\nPhonepe Pulse Data Visualization and Exploration:\nA User-Friendly Tool Using Streamlit and Plotly\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n#streamlit #datavisualization #python\n🔗 Join us on this exciting data-driven journey as we explore the world of YouTube data and unlock the potential of data science!\n\nSubscribe to our channel for more insightful projects, tutorials, and data science content. Let's uncover the power of data together!",
#   'Published_Date': '2023-11-23T09:24:35Z',
#   'Duration': 'PT17M46S',
#   'Views': '2532',
#   'Likes': '52',
#   'Comments': '56',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Title': 'PhonePe Pulse Data Visualization and Exploration|Convert to Dataframe4|part 1.4|Streamlit and Plotly',
#   'Tags': ['PhonePe',
#    'DataVisualization in tamil',
#    'DataExploration in tamil',
#    'Streamlit in tamil',
#    'Plotly in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'phonepe pulse data visualization and exploration project tamil',
#    'phonepe pulse data visualization github in tamil',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'how to create a dataframe tamil',
#    'plotly tamil',
#    'streamlit tamil',
#    'phonepe project explanation tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Bqgjq6NGL4c/default.jpg',
#   'Description': "PhonePe has emerged as a leader among digital payment platforms, catering to millions of users for their daily transactions. Renowned for its user-friendly interface, rapid and secure payment processing, and innovative features, PhonePe has garnered accolades and recognition within the industry.\n\nIn the PhonePe Pulse Data Visualization and Exploration project, we embark on a mission to extract valuable insights from PhonePe's GitHub repository. Our goal is to meticulously process this data and present it through an interactive dashboard that captivates with its visual appeal. This endeavor is made possible by leveraging the power of Python, Streamlit, and Plotly.\n\nPhonepe Pulse Data Visualization and Exploration:\nA User-Friendly Tool Using Streamlit and Plotly\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n#streamlit #datavisualization #python\n🔗 Join us on this exciting data-driven journey as we explore the world of YouTube data and unlock the potential of data science!\n\nSubscribe to our channel for more insightful projects, tutorials, and data science content. Let's uncover the power of data together!",
#   'Published_Date': '2023-11-23T09:24:35Z',
#   'Duration': 'PT17M46S',
#   'Views': '2532',
#   'Likes': '52',
#   'Comments': '56',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Title': 'PhonePe Pulse Data Visualization and Exploration|Convert to Dataframe4|part 1.4|Streamlit and Plotly',
#   'Tags': ['PhonePe',
#    'DataVisualization in tamil',
#    'DataExploration in tamil',
#    'Streamlit in tamil',
#    'Plotly in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'phonepe pulse data visualization and exploration project tamil',
#    'phonepe pulse data visualization github in tamil',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'how to create a dataframe tamil',
#    'plotly tamil',
#    'streamlit tamil',
#    'phonepe project explanation tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Bqgjq6NGL4c/default.jpg',
#   'Description': "PhonePe has emerged as a leader among digital payment platforms, catering to millions of users for their daily transactions. Renowned for its user-friendly interface, rapid and secure payment processing, and innovative features, PhonePe has garnered accolades and recognition within the industry.\n\nIn the PhonePe Pulse Data Visualization and Exploration project, we embark on a mission to extract valuable insights from PhonePe's GitHub repository. Our goal is to meticulously process this data and present it through an interactive dashboard that captivates with its visual appeal. This endeavor is made possible by leveraging the power of Python, Streamlit, and Plotly.\n\nPhonepe Pulse Data Visualization and Exploration:\nA User-Friendly Tool Using Streamlit and Plotly\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n#streamlit #datavisualization #python\n🔗 Join us on this exciting data-driven journey as we explore the world of YouTube data and unlock the potential of data science!\n\nSubscribe to our channel for more insightful projects, tutorials, and data science content. Let's uncover the power of data together!",
#   'Published_Date': '2023-11-23T09:24:35Z',
#   'Duration': 'PT17M46S',
#   'Views': '2532',
#   'Likes': '52',
#   'Comments': '56',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Data Science Tamil',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Title': 'PhonePe Pulse Data Visualization and Exploration|Convert to Dataframe4|part 1.4|Streamlit and Plotly',
#   'Tags': ['PhonePe',
#    'DataVisualization in tamil',
#    'DataExploration in tamil',
#    'Streamlit in tamil',
#    'Plotly in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'phonepe pulse data visualization and exploration project tamil',
#    'phonepe pulse data visualization github in tamil',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'how to create a dataframe tamil',
#    'plotly tamil',
#    'streamlit tamil',
#    'phonepe project explanation tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Bqgjq6NGL4c/default.jpg',
#   'Description': "PhonePe has emerged as a leader among digital payment platforms, catering to millions of users for their daily transactions. Renowned for its user-friendly interface, rapid and secure payment processing, and innovative features, PhonePe has garnered accolades and recognition within the industry.\n\nIn the PhonePe Pulse Data Visualization and Exploration project, we embark on a mission to extract valuable insights from PhonePe's GitHub repository. Our goal is to meticulously process this data and present it through an interactive dashboard that captivates with its visual appeal. This endeavor is made possible by leveraging the power of Python, Streamlit, and Plotly.\n\nPhonepe Pulse Data Visualization and Exploration:\nA User-Friendly Tool Using Streamlit and Plotly\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n#streamlit #datavisualization #python\n🔗 Join us on this exciting data-driven journey as we explore the world of YouTube data and unlock the potential of data science!\n\nSubscribe to our channel for more insightful projects, tutorials, and data science content. Let's uncover the power of data together!",
#   'Published_Date': '2023-11-23T09:24:35Z',
#   'Duration': 'PT17M46S',
#   'Views': '2532',
#   'Likes': '52',
#   'Comments': '56',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
len(video_details)
# Out:
# 71

# %%
# K-Talk Movies="UCydCXKxPQnCZi-jW9PtAFaQ"
# Mark Booster="UC-G4nVvDVFwh47uBsvQP_OA"
# Madan Gowri="UCY6KjrDBN_tIRFT_QNqQbRQ"
# Data Science Tamil= "UCuI5XcJYynHa5k_lqDzAgwQ"
# SNT Loves="UCP6PUCbqn2sMu5OZcPdkN6Q"

# %%
#Get Comment information
def get_comment_info(video_ids):
    Comment_data=[]
    for video_id in video_ids:
        request=youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=50
            )
        response=request.execute()

        for item in response['items']:
            data=dict(Comment_Id=item["snippet"]["topLevelComment"]["id"],
                    Video_Id=item["snippet"]["topLevelComment"]["snippet"]["videoId"],
                    Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                    Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                    Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
            
            Comment_data.append(data)

        
            
    return Comment_data

# %%
comment_details=get_comment_info(Video_Ids)

# %%
comment_details
# Out:
# [{'Comment_Id': 'Ugxj2onJUdhrnQpWrj14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Brother kindly share me ur mail id',
#   'Comment_Author': '@v_see_you',
#   'Comment_Published': '2024-08-03T05:41:35Z'},
#  {'Comment_Id': 'UgzZQcwRiuR-CMjG_ox4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Give your insta id',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:37Z'},
#  {'Comment_Id': 'Ugzl87QynrTolzYDkWR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:12Z'},
#  {'Comment_Id': 'UgyeVVFeYK1ZUhFgqJR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro i need ah help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:00Z'},
#  {'Comment_Id': 'UgyChKONaDVL_PiOv-h4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please  bro airbnb start panunga bro',
#   'Comment_Author': '@murugalakshmiram5582',
#   'Comment_Published': '2024-06-22T05:18:48Z'},
#  {'Comment_Id': 'Ugxfh8FYdD-egdR1Yjt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next next project epa start panuvinga',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:32:47Z'},
#  {'Comment_Id': 'UgwCa_dJXul1OFYr2gV4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Inga elarume guvi student aa',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:27:52Z'},
#  {'Comment_Id': 'UgwMM5BfW1cUUkBuMBN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro air bnb eppo bro poduvinga?',
#   'Comment_Author': '@rsaakash5640',
#   'Comment_Published': '2024-06-18T12:42:39Z'},
#  {'Comment_Id': 'UgzTEIcP2rfsJorcwjB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro airbnb',
#   'Comment_Author': '@TamilMani-xk8jp',
#   'Comment_Published': '2024-06-07T05:12:38Z'},
#  {'Comment_Id': 'Ugy1bGTLoqkMF_kyB-t4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Thanks a lot bro.....🙂',
#   'Comment_Author': '@ramyamahesh5321',
#   'Comment_Published': '2024-06-03T09:15:30Z'},
#  {'Comment_Id': 'UgyOHEVSVuYq-uLl53B4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Anna unga final project guvi la enna naa????',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-28T13:48:53Z'},
#  {'Comment_Id': 'UgzqTpj2b6UQTSC_5Ip4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'anna neenga final project finish pannigala,pannigana link pls send pannugaa',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-25T13:52:23Z'},
#  {'Comment_Id': 'UgyiHC2UD2Mkg6cybcx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Start Airbnb bro 😢',
#   'Comment_Author': '@mounisht9775',
#   'Comment_Published': '2024-05-05T18:30:30Z'},
#  {'Comment_Id': 'Ugw4lvgUvapsdhvoaYt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project  start panungaa',
#   'Comment_Author': '@umaiyaumaiya9397',
#   'Comment_Published': '2024-05-02T11:00:07Z'},
#  {'Comment_Id': 'Ugw_g2KBjwUBjjz5ezx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-23T17:04:25Z'},
#  {'Comment_Id': 'UgxT1RzfpT4e9Qg5oZt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro can you give airbnb dataset csv link ?',
#   'Comment_Author': '@sgigadsgigad4019',
#   'Comment_Published': '2024-04-22T14:06:10Z'},
#  {'Comment_Id': 'UgwChSBzrOnb46BiNjN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro please start with next project airbnb bro please',
#   'Comment_Author': '@chopravalarmathi4588',
#   'Comment_Published': '2024-04-19T15:42:54Z'},
#  {'Comment_Id': 'UgyxITJFxOHcS-1SCTF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro please start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-16T13:45:34Z'},
#  {'Comment_Id': 'UgzRoFJgFDdLGzmd9mZ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro OCR PROJECT finished aa intha video la',
#   'Comment_Author': '@naufalmohamed',
#   'Comment_Published': '2024-04-15T11:02:21Z'},
#  {'Comment_Id': 'UgwdzonrSBxPf_cDFNF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro when starting Airbnb',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-12T09:50:57Z'},
#  {'Comment_Id': 'UgwwN0A7Q58ros1Yztt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project epo strat pannuvinga bro airbnb',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-11T04:42:30Z'},
#  {'Comment_Id': 'UgztB3jZp8Av1ie15eB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Aibhb project start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-09T06:43:32Z'},
#  {'Comment_Id': 'UgwzUBXsbQ_xfHALtRB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:28Z'},
#  {'Comment_Id': 'UgwM2MmksFypI0OqMD54AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro complete aa',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:14Z'},
#  {'Comment_Id': 'UgzpE7MKMAVj3ucDmYN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro next project epo upload panuveenga, upload panna work pani2 irukeengala, please rply bro',
#   'Comment_Author': '@qwertypad123',
#   'Comment_Published': '2024-04-03T14:21:20Z'},
#  {'Comment_Id': 'Ugyj-Hkr4j-_oL4_XTJ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Plss start Airbnb project bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-02T07:04:51Z'},
#  {'Comment_Id': 'UgyFCWPk2osM6PTykwp4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro you got a certificate from guvi',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-01T03:40:50Z'},
#  {'Comment_Id': 'Ugxu-94HubHyNwSocGF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Hi brother pls can teach us  airbnb project',
#   'Comment_Author': '@srivanikothavadla8977',
#   'Comment_Published': '2024-03-29T16:30:52Z'},
#  {'Comment_Id': 'UgzYqK9WcnnK1cRFAy14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Videos avolo thana bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-03-28T04:45:16Z'},
#  {'Comment_Id': 'Ugxj2onJUdhrnQpWrj14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Brother kindly share me ur mail id',
#   'Comment_Author': '@v_see_you',
#   'Comment_Published': '2024-08-03T05:41:35Z'},
#  {'Comment_Id': 'UgzZQcwRiuR-CMjG_ox4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Give your insta id',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:37Z'},
#  {'Comment_Id': 'Ugzl87QynrTolzYDkWR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:12Z'},
#  {'Comment_Id': 'UgyeVVFeYK1ZUhFgqJR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro i need ah help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:00Z'},
#  {'Comment_Id': 'UgyChKONaDVL_PiOv-h4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please  bro airbnb start panunga bro',
#   'Comment_Author': '@murugalakshmiram5582',
#   'Comment_Published': '2024-06-22T05:18:48Z'},
#  {'Comment_Id': 'Ugxfh8FYdD-egdR1Yjt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next next project epa start panuvinga',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:32:47Z'},
#  {'Comment_Id': 'UgwCa_dJXul1OFYr2gV4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Inga elarume guvi student aa',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:27:52Z'},
#  {'Comment_Id': 'UgwMM5BfW1cUUkBuMBN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro air bnb eppo bro poduvinga?',
#   'Comment_Author': '@rsaakash5640',
#   'Comment_Published': '2024-06-18T12:42:39Z'},
#  {'Comment_Id': 'UgzTEIcP2rfsJorcwjB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro airbnb',
#   'Comment_Author': '@TamilMani-xk8jp',
#   'Comment_Published': '2024-06-07T05:12:38Z'},
#  {'Comment_Id': 'Ugy1bGTLoqkMF_kyB-t4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Thanks a lot bro.....🙂',
#   'Comment_Author': '@ramyamahesh5321',
#   'Comment_Published': '2024-06-03T09:15:30Z'},
#  {'Comment_Id': 'UgyOHEVSVuYq-uLl53B4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Anna unga final project guvi la enna naa????',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-28T13:48:53Z'},
#  {'Comment_Id': 'UgzqTpj2b6UQTSC_5Ip4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'anna neenga final project finish pannigala,pannigana link pls send pannugaa',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-25T13:52:23Z'},
#  {'Comment_Id': 'UgyiHC2UD2Mkg6cybcx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Start Airbnb bro 😢',
#   'Comment_Author': '@mounisht9775',
#   'Comment_Published': '2024-05-05T18:30:30Z'},
#  {'Comment_Id': 'Ugw4lvgUvapsdhvoaYt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project  start panungaa',
#   'Comment_Author': '@umaiyaumaiya9397',
#   'Comment_Published': '2024-05-02T11:00:07Z'},
#  {'Comment_Id': 'Ugw_g2KBjwUBjjz5ezx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-23T17:04:25Z'},
#  {'Comment_Id': 'UgxT1RzfpT4e9Qg5oZt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro can you give airbnb dataset csv link ?',
#   'Comment_Author': '@sgigadsgigad4019',
#   'Comment_Published': '2024-04-22T14:06:10Z'},
#  {'Comment_Id': 'UgwChSBzrOnb46BiNjN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro please start with next project airbnb bro please',
#   'Comment_Author': '@chopravalarmathi4588',
#   'Comment_Published': '2024-04-19T15:42:54Z'},
#  {'Comment_Id': 'UgyxITJFxOHcS-1SCTF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro please start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-16T13:45:34Z'},
#  {'Comment_Id': 'UgzRoFJgFDdLGzmd9mZ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro OCR PROJECT finished aa intha video la',
#   'Comment_Author': '@naufalmohamed',
#   'Comment_Published': '2024-04-15T11:02:21Z'},
#  {'Comment_Id': 'UgwdzonrSBxPf_cDFNF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro when starting Airbnb',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-12T09:50:57Z'},
#  {'Comment_Id': 'UgwwN0A7Q58ros1Yztt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project epo strat pannuvinga bro airbnb',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-11T04:42:30Z'},
#  {'Comment_Id': 'UgztB3jZp8Av1ie15eB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Aibhb project start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-09T06:43:32Z'},
#  {'Comment_Id': 'UgwzUBXsbQ_xfHALtRB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:28Z'},
#  {'Comment_Id': 'UgwM2MmksFypI0OqMD54AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro complete aa',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:14Z'},
#  {'Comment_Id': 'UgzpE7MKMAVj3ucDmYN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro next project epo upload panuveenga, upload panna work pani2 irukeengala, please rply bro',
#   'Comment_Author': '@qwertypad123',
#   'Comment_Published': '2024-04-03T14:21:20Z'},
#  {'Comment_Id': 'Ugyj-Hkr4j-_oL4_XTJ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Plss start Airbnb project bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-02T07:04:51Z'},
#  {'Comment_Id': 'UgyFCWPk2osM6PTykwp4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro you got a certificate from guvi',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-01T03:40:50Z'},
#  {'Comment_Id': 'Ugxu-94HubHyNwSocGF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Hi brother pls can teach us  airbnb project',
#   'Comment_Author': '@srivanikothavadla8977',
#   'Comment_Published': '2024-03-29T16:30:52Z'},
#  {'Comment_Id': 'UgzYqK9WcnnK1cRFAy14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Videos avolo thana bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-03-28T04:45:16Z'},
#  {'Comment_Id': 'Ugxj2onJUdhrnQpWrj14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Brother kindly share me ur mail id',
#   'Comment_Author': '@v_see_you',
#   'Comment_Published': '2024-08-03T05:41:35Z'},
#  {'Comment_Id': 'UgzZQcwRiuR-CMjG_ox4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Give your insta id',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:37Z'},
#  {'Comment_Id': 'Ugzl87QynrTolzYDkWR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:12Z'},
#  {'Comment_Id': 'UgyeVVFeYK1ZUhFgqJR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro i need ah help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:00Z'},
#  {'Comment_Id': 'UgyChKONaDVL_PiOv-h4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please  bro airbnb start panunga bro',
#   'Comment_Author': '@murugalakshmiram5582',
#   'Comment_Published': '2024-06-22T05:18:48Z'},
#  {'Comment_Id': 'Ugxfh8FYdD-egdR1Yjt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next next project epa start panuvinga',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:32:47Z'},
#  {'Comment_Id': 'UgwCa_dJXul1OFYr2gV4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Inga elarume guvi student aa',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:27:52Z'},
#  {'Comment_Id': 'UgwMM5BfW1cUUkBuMBN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro air bnb eppo bro poduvinga?',
#   'Comment_Author': '@rsaakash5640',
#   'Comment_Published': '2024-06-18T12:42:39Z'},
#  {'Comment_Id': 'UgzTEIcP2rfsJorcwjB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro airbnb',
#   'Comment_Author': '@TamilMani-xk8jp',
#   'Comment_Published': '2024-06-07T05:12:38Z'},
#  {'Comment_Id': 'Ugy1bGTLoqkMF_kyB-t4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Thanks a lot bro.....🙂',
#   'Comment_Author': '@ramyamahesh5321',
#   'Comment_Published': '2024-06-03T09:15:30Z'},
#  {'Comment_Id': 'UgyOHEVSVuYq-uLl53B4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Anna unga final project guvi la enna naa????',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-28T13:48:53Z'},
#  {'Comment_Id': 'UgzqTpj2b6UQTSC_5Ip4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'anna neenga final project finish pannigala,pannigana link pls send pannugaa',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-25T13:52:23Z'},
#  {'Comment_Id': 'UgyiHC2UD2Mkg6cybcx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Start Airbnb bro 😢',
#   'Comment_Author': '@mounisht9775',
#   'Comment_Published': '2024-05-05T18:30:30Z'},
#  {'Comment_Id': 'Ugw4lvgUvapsdhvoaYt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project  start panungaa',
#   'Comment_Author': '@umaiyaumaiya9397',
#   'Comment_Published': '2024-05-02T11:00:07Z'},
#  {'Comment_Id': 'Ugw_g2KBjwUBjjz5ezx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-23T17:04:25Z'},
#  {'Comment_Id': 'UgxT1RzfpT4e9Qg5oZt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro can you give airbnb dataset csv link ?',
#   'Comment_Author': '@sgigadsgigad4019',
#   'Comment_Published': '2024-04-22T14:06:10Z'},
#  {'Comment_Id': 'UgwChSBzrOnb46BiNjN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro please start with next project airbnb bro please',
#   'Comment_Author': '@chopravalarmathi4588',
#   'Comment_Published': '2024-04-19T15:42:54Z'},
#  {'Comment_Id': 'UgyxITJFxOHcS-1SCTF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro please start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-16T13:45:34Z'},
#  {'Comment_Id': 'UgzRoFJgFDdLGzmd9mZ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro OCR PROJECT finished aa intha video la',
#   'Comment_Author': '@naufalmohamed',
#   'Comment_Published': '2024-04-15T11:02:21Z'},
#  {'Comment_Id': 'UgwdzonrSBxPf_cDFNF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro when starting Airbnb',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-12T09:50:57Z'},
#  {'Comment_Id': 'UgwwN0A7Q58ros1Yztt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project epo strat pannuvinga bro airbnb',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-11T04:42:30Z'},
#  {'Comment_Id': 'UgztB3jZp8Av1ie15eB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Aibhb project start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-09T06:43:32Z'},
#  {'Comment_Id': 'UgwzUBXsbQ_xfHALtRB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:28Z'},
#  {'Comment_Id': 'UgwM2MmksFypI0OqMD54AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro complete aa',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:14Z'},
#  {'Comment_Id': 'UgzpE7MKMAVj3ucDmYN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro next project epo upload panuveenga, upload panna work pani2 irukeengala, please rply bro',
#   'Comment_Author': '@qwertypad123',
#   'Comment_Published': '2024-04-03T14:21:20Z'},
#  {'Comment_Id': 'Ugyj-Hkr4j-_oL4_XTJ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Plss start Airbnb project bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-02T07:04:51Z'},
#  {'Comment_Id': 'UgyFCWPk2osM6PTykwp4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro you got a certificate from guvi',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-01T03:40:50Z'},
#  {'Comment_Id': 'Ugxu-94HubHyNwSocGF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Hi brother pls can teach us  airbnb project',
#   'Comment_Author': '@srivanikothavadla8977',
#   'Comment_Published': '2024-03-29T16:30:52Z'},
#  {'Comment_Id': 'UgzYqK9WcnnK1cRFAy14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Videos avolo thana bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-03-28T04:45:16Z'},
#  {'Comment_Id': 'Ugxj2onJUdhrnQpWrj14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Brother kindly share me ur mail id',
#   'Comment_Author': '@v_see_you',
#   'Comment_Published': '2024-08-03T05:41:35Z'},
#  {'Comment_Id': 'UgzZQcwRiuR-CMjG_ox4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Give your insta id',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:37Z'},
#  {'Comment_Id': 'Ugzl87QynrTolzYDkWR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:12Z'},
#  {'Comment_Id': 'UgyeVVFeYK1ZUhFgqJR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro i need ah help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:00Z'},
#  {'Comment_Id': 'UgyChKONaDVL_PiOv-h4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please  bro airbnb start panunga bro',
#   'Comment_Author': '@murugalakshmiram5582',
#   'Comment_Published': '2024-06-22T05:18:48Z'},
#  {'Comment_Id': 'Ugxfh8FYdD-egdR1Yjt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next next project epa start panuvinga',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:32:47Z'},
#  {'Comment_Id': 'UgwCa_dJXul1OFYr2gV4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Inga elarume guvi student aa',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:27:52Z'},
#  {'Comment_Id': 'UgwMM5BfW1cUUkBuMBN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro air bnb eppo bro poduvinga?',
#   'Comment_Author': '@rsaakash5640',
#   'Comment_Published': '2024-06-18T12:42:39Z'},
#  {'Comment_Id': 'UgzTEIcP2rfsJorcwjB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro airbnb',
#   'Comment_Author': '@TamilMani-xk8jp',
#   'Comment_Published': '2024-06-07T05:12:38Z'},
#  {'Comment_Id': 'Ugy1bGTLoqkMF_kyB-t4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Thanks a lot bro.....🙂',
#   'Comment_Author': '@ramyamahesh5321',
#   'Comment_Published': '2024-06-03T09:15:30Z'},
#  {'Comment_Id': 'UgyOHEVSVuYq-uLl53B4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Anna unga final project guvi la enna naa????',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-28T13:48:53Z'},
#  {'Comment_Id': 'UgzqTpj2b6UQTSC_5Ip4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'anna neenga final project finish pannigala,pannigana link pls send pannugaa',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-25T13:52:23Z'},
#  {'Comment_Id': 'UgyiHC2UD2Mkg6cybcx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Start Airbnb bro 😢',
#   'Comment_Author': '@mounisht9775',
#   'Comment_Published': '2024-05-05T18:30:30Z'},
#  {'Comment_Id': 'Ugw4lvgUvapsdhvoaYt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project  start panungaa',
#   'Comment_Author': '@umaiyaumaiya9397',
#   'Comment_Published': '2024-05-02T11:00:07Z'},
#  {'Comment_Id': 'Ugw_g2KBjwUBjjz5ezx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-23T17:04:25Z'},
#  {'Comment_Id': 'UgxT1RzfpT4e9Qg5oZt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro can you give airbnb dataset csv link ?',
#   'Comment_Author': '@sgigadsgigad4019',
#   'Comment_Published': '2024-04-22T14:06:10Z'},
#  {'Comment_Id': 'UgwChSBzrOnb46BiNjN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro please start with next project airbnb bro please',
#   'Comment_Author': '@chopravalarmathi4588',
#   'Comment_Published': '2024-04-19T15:42:54Z'},
#  {'Comment_Id': 'UgyxITJFxOHcS-1SCTF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro please start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-16T13:45:34Z'},
#  {'Comment_Id': 'UgzRoFJgFDdLGzmd9mZ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro OCR PROJECT finished aa intha video la',
#   'Comment_Author': '@naufalmohamed',
#   'Comment_Published': '2024-04-15T11:02:21Z'},
#  {'Comment_Id': 'UgwdzonrSBxPf_cDFNF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro when starting Airbnb',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-12T09:50:57Z'},
#  {'Comment_Id': 'UgwwN0A7Q58ros1Yztt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project epo strat pannuvinga bro airbnb',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-11T04:42:30Z'},
#  {'Comment_Id': 'UgztB3jZp8Av1ie15eB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Aibhb project start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-09T06:43:32Z'},
#  {'Comment_Id': 'UgwzUBXsbQ_xfHALtRB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:28Z'},
#  {'Comment_Id': 'UgwM2MmksFypI0OqMD54AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro complete aa',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:14Z'},
#  {'Comment_Id': 'UgzpE7MKMAVj3ucDmYN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro next project epo upload panuveenga, upload panna work pani2 irukeengala, please rply bro',
#   'Comment_Author': '@qwertypad123',
#   'Comment_Published': '2024-04-03T14:21:20Z'},
#  {'Comment_Id': 'Ugyj-Hkr4j-_oL4_XTJ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Plss start Airbnb project bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-02T07:04:51Z'},
#  {'Comment_Id': 'UgyFCWPk2osM6PTykwp4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro you got a certificate from guvi',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-01T03:40:50Z'},
#  {'Comment_Id': 'Ugxu-94HubHyNwSocGF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Hi brother pls can teach us  airbnb project',
#   'Comment_Author': '@srivanikothavadla8977',
#   'Comment_Published': '2024-03-29T16:30:52Z'},
#  {'Comment_Id': 'UgzYqK9WcnnK1cRFAy14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Videos avolo thana bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-03-28T04:45:16Z'},
#  {'Comment_Id': 'Ugxj2onJUdhrnQpWrj14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Brother kindly share me ur mail id',
#   'Comment_Author': '@v_see_you',
#   'Comment_Published': '2024-08-03T05:41:35Z'},
#  {'Comment_Id': 'UgzZQcwRiuR-CMjG_ox4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Give your insta id',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:37Z'},
#  {'Comment_Id': 'Ugzl87QynrTolzYDkWR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:12Z'},
#  {'Comment_Id': 'UgyeVVFeYK1ZUhFgqJR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro i need ah help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:00Z'},
#  {'Comment_Id': 'UgyChKONaDVL_PiOv-h4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please  bro airbnb start panunga bro',
#   'Comment_Author': '@murugalakshmiram5582',
#   'Comment_Published': '2024-06-22T05:18:48Z'},
#  {'Comment_Id': 'Ugxfh8FYdD-egdR1Yjt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next next project epa start panuvinga',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:32:47Z'},
#  {'Comment_Id': 'UgwCa_dJXul1OFYr2gV4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Inga elarume guvi student aa',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:27:52Z'},
#  {'Comment_Id': 'UgwMM5BfW1cUUkBuMBN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro air bnb eppo bro poduvinga?',
#   'Comment_Author': '@rsaakash5640',
#   'Comment_Published': '2024-06-18T12:42:39Z'},
#  {'Comment_Id': 'UgzTEIcP2rfsJorcwjB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro airbnb',
#   'Comment_Author': '@TamilMani-xk8jp',
#   'Comment_Published': '2024-06-07T05:12:38Z'},
#  {'Comment_Id': 'Ugy1bGTLoqkMF_kyB-t4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Thanks a lot bro.....🙂',
#   'Comment_Author': '@ramyamahesh5321',
#   'Comment_Published': '2024-06-03T09:15:30Z'},
#  {'Comment_Id': 'UgyOHEVSVuYq-uLl53B4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Anna unga final project guvi la enna naa????',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-28T13:48:53Z'},
#  {'Comment_Id': 'UgzqTpj2b6UQTSC_5Ip4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'anna neenga final project finish pannigala,pannigana link pls send pannugaa',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-25T13:52:23Z'},
#  {'Comment_Id': 'UgyiHC2UD2Mkg6cybcx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Start Airbnb bro 😢',
#   'Comment_Author': '@mounisht9775',
#   'Comment_Published': '2024-05-05T18:30:30Z'},
#  {'Comment_Id': 'Ugw4lvgUvapsdhvoaYt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project  start panungaa',
#   'Comment_Author': '@umaiyaumaiya9397',
#   'Comment_Published': '2024-05-02T11:00:07Z'},
#  {'Comment_Id': 'Ugw_g2KBjwUBjjz5ezx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-23T17:04:25Z'},
#  {'Comment_Id': 'UgxT1RzfpT4e9Qg5oZt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro can you give airbnb dataset csv link ?',
#   'Comment_Author': '@sgigadsgigad4019',
#   'Comment_Published': '2024-04-22T14:06:10Z'},
#  {'Comment_Id': 'UgwChSBzrOnb46BiNjN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro please start with next project airbnb bro please',
#   'Comment_Author': '@chopravalarmathi4588',
#   'Comment_Published': '2024-04-19T15:42:54Z'},
#  {'Comment_Id': 'UgyxITJFxOHcS-1SCTF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro please start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-16T13:45:34Z'},
#  {'Comment_Id': 'UgzRoFJgFDdLGzmd9mZ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro OCR PROJECT finished aa intha video la',
#   'Comment_Author': '@naufalmohamed',
#   'Comment_Published': '2024-04-15T11:02:21Z'},
#  {'Comment_Id': 'UgwdzonrSBxPf_cDFNF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro when starting Airbnb',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-12T09:50:57Z'},
#  {'Comment_Id': 'UgwwN0A7Q58ros1Yztt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project epo strat pannuvinga bro airbnb',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-11T04:42:30Z'},
#  {'Comment_Id': 'UgztB3jZp8Av1ie15eB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Aibhb project start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-09T06:43:32Z'},
#  {'Comment_Id': 'UgwzUBXsbQ_xfHALtRB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:28Z'},
#  {'Comment_Id': 'UgwM2MmksFypI0OqMD54AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro complete aa',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:14Z'},
#  {'Comment_Id': 'UgzpE7MKMAVj3ucDmYN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro next project epo upload panuveenga, upload panna work pani2 irukeengala, please rply bro',
#   'Comment_Author': '@qwertypad123',
#   'Comment_Published': '2024-04-03T14:21:20Z'},
#  {'Comment_Id': 'Ugyj-Hkr4j-_oL4_XTJ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Plss start Airbnb project bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-02T07:04:51Z'},
#  {'Comment_Id': 'UgyFCWPk2osM6PTykwp4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro you got a certificate from guvi',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-01T03:40:50Z'},
#  {'Comment_Id': 'Ugxu-94HubHyNwSocGF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Hi brother pls can teach us  airbnb project',
#   'Comment_Author': '@srivanikothavadla8977',
#   'Comment_Published': '2024-03-29T16:30:52Z'},
#  {'Comment_Id': 'UgzYqK9WcnnK1cRFAy14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Videos avolo thana bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-03-28T04:45:16Z'},
#  {'Comment_Id': 'Ugxj2onJUdhrnQpWrj14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Brother kindly share me ur mail id',
#   'Comment_Author': '@v_see_you',
#   'Comment_Published': '2024-08-03T05:41:35Z'},
#  {'Comment_Id': 'UgzZQcwRiuR-CMjG_ox4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Give your insta id',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:37Z'},
#  {'Comment_Id': 'Ugzl87QynrTolzYDkWR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:12Z'},
#  {'Comment_Id': 'UgyeVVFeYK1ZUhFgqJR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro i need ah help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:00Z'},
#  {'Comment_Id': 'UgyChKONaDVL_PiOv-h4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please  bro airbnb start panunga bro',
#   'Comment_Author': '@murugalakshmiram5582',
#   'Comment_Published': '2024-06-22T05:18:48Z'},
#  {'Comment_Id': 'Ugxfh8FYdD-egdR1Yjt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next next project epa start panuvinga',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:32:47Z'},
#  {'Comment_Id': 'UgwCa_dJXul1OFYr2gV4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Inga elarume guvi student aa',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:27:52Z'},
#  {'Comment_Id': 'UgwMM5BfW1cUUkBuMBN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro air bnb eppo bro poduvinga?',
#   'Comment_Author': '@rsaakash5640',
#   'Comment_Published': '2024-06-18T12:42:39Z'},
#  {'Comment_Id': 'UgzTEIcP2rfsJorcwjB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro airbnb',
#   'Comment_Author': '@TamilMani-xk8jp',
#   'Comment_Published': '2024-06-07T05:12:38Z'},
#  {'Comment_Id': 'Ugy1bGTLoqkMF_kyB-t4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Thanks a lot bro.....🙂',
#   'Comment_Author': '@ramyamahesh5321',
#   'Comment_Published': '2024-06-03T09:15:30Z'},
#  {'Comment_Id': 'UgyOHEVSVuYq-uLl53B4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Anna unga final project guvi la enna naa????',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-28T13:48:53Z'},
#  {'Comment_Id': 'UgzqTpj2b6UQTSC_5Ip4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'anna neenga final project finish pannigala,pannigana link pls send pannugaa',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-25T13:52:23Z'},
#  {'Comment_Id': 'UgyiHC2UD2Mkg6cybcx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Start Airbnb bro 😢',
#   'Comment_Author': '@mounisht9775',
#   'Comment_Published': '2024-05-05T18:30:30Z'},
#  {'Comment_Id': 'Ugw4lvgUvapsdhvoaYt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project  start panungaa',
#   'Comment_Author': '@umaiyaumaiya9397',
#   'Comment_Published': '2024-05-02T11:00:07Z'},
#  {'Comment_Id': 'Ugw_g2KBjwUBjjz5ezx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-23T17:04:25Z'},
#  {'Comment_Id': 'UgxT1RzfpT4e9Qg5oZt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro can you give airbnb dataset csv link ?',
#   'Comment_Author': '@sgigadsgigad4019',
#   'Comment_Published': '2024-04-22T14:06:10Z'},
#  {'Comment_Id': 'UgwChSBzrOnb46BiNjN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro please start with next project airbnb bro please',
#   'Comment_Author': '@chopravalarmathi4588',
#   'Comment_Published': '2024-04-19T15:42:54Z'},
#  {'Comment_Id': 'UgyxITJFxOHcS-1SCTF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro please start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-16T13:45:34Z'},
#  {'Comment_Id': 'UgzRoFJgFDdLGzmd9mZ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro OCR PROJECT finished aa intha video la',
#   'Comment_Author': '@naufalmohamed',
#   'Comment_Published': '2024-04-15T11:02:21Z'},
#  {'Comment_Id': 'UgwdzonrSBxPf_cDFNF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro when starting Airbnb',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-12T09:50:57Z'},
#  {'Comment_Id': 'UgwwN0A7Q58ros1Yztt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project epo strat pannuvinga bro airbnb',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-11T04:42:30Z'},
#  {'Comment_Id': 'UgztB3jZp8Av1ie15eB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Aibhb project start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-09T06:43:32Z'},
#  {'Comment_Id': 'UgwzUBXsbQ_xfHALtRB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:28Z'},
#  {'Comment_Id': 'UgwM2MmksFypI0OqMD54AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro complete aa',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:14Z'},
#  {'Comment_Id': 'UgzpE7MKMAVj3ucDmYN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro next project epo upload panuveenga, upload panna work pani2 irukeengala, please rply bro',
#   'Comment_Author': '@qwertypad123',
#   'Comment_Published': '2024-04-03T14:21:20Z'},
#  {'Comment_Id': 'Ugyj-Hkr4j-_oL4_XTJ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Plss start Airbnb project bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-02T07:04:51Z'},
#  {'Comment_Id': 'UgyFCWPk2osM6PTykwp4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro you got a certificate from guvi',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-01T03:40:50Z'},
#  {'Comment_Id': 'Ugxu-94HubHyNwSocGF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Hi brother pls can teach us  airbnb project',
#   'Comment_Author': '@srivanikothavadla8977',
#   'Comment_Published': '2024-03-29T16:30:52Z'},
#  {'Comment_Id': 'UgzYqK9WcnnK1cRFAy14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Videos avolo thana bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-03-28T04:45:16Z'},
#  {'Comment_Id': 'Ugxj2onJUdhrnQpWrj14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Brother kindly share me ur mail id',
#   'Comment_Author': '@v_see_you',
#   'Comment_Published': '2024-08-03T05:41:35Z'},
#  {'Comment_Id': 'UgzZQcwRiuR-CMjG_ox4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Give your insta id',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:37Z'},
#  {'Comment_Id': 'Ugzl87QynrTolzYDkWR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:12Z'},
#  {'Comment_Id': 'UgyeVVFeYK1ZUhFgqJR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro i need ah help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:00Z'},
#  {'Comment_Id': 'UgyChKONaDVL_PiOv-h4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please  bro airbnb start panunga bro',
#   'Comment_Author': '@murugalakshmiram5582',
#   'Comment_Published': '2024-06-22T05:18:48Z'},
#  {'Comment_Id': 'Ugxfh8FYdD-egdR1Yjt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next next project epa start panuvinga',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:32:47Z'},
#  {'Comment_Id': 'UgwCa_dJXul1OFYr2gV4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Inga elarume guvi student aa',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:27:52Z'},
#  {'Comment_Id': 'UgwMM5BfW1cUUkBuMBN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro air bnb eppo bro poduvinga?',
#   'Comment_Author': '@rsaakash5640',
#   'Comment_Published': '2024-06-18T12:42:39Z'},
#  {'Comment_Id': 'UgzTEIcP2rfsJorcwjB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro airbnb',
#   'Comment_Author': '@TamilMani-xk8jp',
#   'Comment_Published': '2024-06-07T05:12:38Z'},
#  {'Comment_Id': 'Ugy1bGTLoqkMF_kyB-t4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Thanks a lot bro.....🙂',
#   'Comment_Author': '@ramyamahesh5321',
#   'Comment_Published': '2024-06-03T09:15:30Z'},
#  {'Comment_Id': 'UgyOHEVSVuYq-uLl53B4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Anna unga final project guvi la enna naa????',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-28T13:48:53Z'},
#  {'Comment_Id': 'UgzqTpj2b6UQTSC_5Ip4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'anna neenga final project finish pannigala,pannigana link pls send pannugaa',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-25T13:52:23Z'},
#  {'Comment_Id': 'UgyiHC2UD2Mkg6cybcx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Start Airbnb bro 😢',
#   'Comment_Author': '@mounisht9775',
#   'Comment_Published': '2024-05-05T18:30:30Z'},
#  {'Comment_Id': 'Ugw4lvgUvapsdhvoaYt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project  start panungaa',
#   'Comment_Author': '@umaiyaumaiya9397',
#   'Comment_Published': '2024-05-02T11:00:07Z'},
#  {'Comment_Id': 'Ugw_g2KBjwUBjjz5ezx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-23T17:04:25Z'},
#  {'Comment_Id': 'UgxT1RzfpT4e9Qg5oZt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro can you give airbnb dataset csv link ?',
#   'Comment_Author': '@sgigadsgigad4019',
#   'Comment_Published': '2024-04-22T14:06:10Z'},
#  {'Comment_Id': 'UgwChSBzrOnb46BiNjN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro please start with next project airbnb bro please',
#   'Comment_Author': '@chopravalarmathi4588',
#   'Comment_Published': '2024-04-19T15:42:54Z'},
#  {'Comment_Id': 'UgyxITJFxOHcS-1SCTF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro please start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-16T13:45:34Z'},
#  {'Comment_Id': 'UgzRoFJgFDdLGzmd9mZ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro OCR PROJECT finished aa intha video la',
#   'Comment_Author': '@naufalmohamed',
#   'Comment_Published': '2024-04-15T11:02:21Z'},
#  {'Comment_Id': 'UgwdzonrSBxPf_cDFNF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro when starting Airbnb',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-12T09:50:57Z'},
#  {'Comment_Id': 'UgwwN0A7Q58ros1Yztt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project epo strat pannuvinga bro airbnb',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-11T04:42:30Z'},
#  {'Comment_Id': 'UgztB3jZp8Av1ie15eB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Aibhb project start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-09T06:43:32Z'},
#  {'Comment_Id': 'UgwzUBXsbQ_xfHALtRB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:28Z'},
#  {'Comment_Id': 'UgwM2MmksFypI0OqMD54AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro complete aa',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:14Z'},
#  {'Comment_Id': 'UgzpE7MKMAVj3ucDmYN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro next project epo upload panuveenga, upload panna work pani2 irukeengala, please rply bro',
#   'Comment_Author': '@qwertypad123',
#   'Comment_Published': '2024-04-03T14:21:20Z'},
#  {'Comment_Id': 'Ugyj-Hkr4j-_oL4_XTJ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Plss start Airbnb project bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-02T07:04:51Z'},
#  {'Comment_Id': 'UgyFCWPk2osM6PTykwp4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro you got a certificate from guvi',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-01T03:40:50Z'},
#  {'Comment_Id': 'Ugxu-94HubHyNwSocGF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Hi brother pls can teach us  airbnb project',
#   'Comment_Author': '@srivanikothavadla8977',
#   'Comment_Published': '2024-03-29T16:30:52Z'},
#  {'Comment_Id': 'UgzYqK9WcnnK1cRFAy14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Videos avolo thana bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-03-28T04:45:16Z'},
#  {'Comment_Id': 'Ugxj2onJUdhrnQpWrj14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Brother kindly share me ur mail id',
#   'Comment_Author': '@v_see_you',
#   'Comment_Published': '2024-08-03T05:41:35Z'},
#  {'Comment_Id': 'UgzZQcwRiuR-CMjG_ox4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Give your insta id',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:37Z'},
#  {'Comment_Id': 'Ugzl87QynrTolzYDkWR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:12Z'},
#  {'Comment_Id': 'UgyeVVFeYK1ZUhFgqJR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro i need ah help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:00Z'},
#  {'Comment_Id': 'UgyChKONaDVL_PiOv-h4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please  bro airbnb start panunga bro',
#   'Comment_Author': '@murugalakshmiram5582',
#   'Comment_Published': '2024-06-22T05:18:48Z'},
#  {'Comment_Id': 'Ugxfh8FYdD-egdR1Yjt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next next project epa start panuvinga',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:32:47Z'},
#  {'Comment_Id': 'UgwCa_dJXul1OFYr2gV4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Inga elarume guvi student aa',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:27:52Z'},
#  {'Comment_Id': 'UgwMM5BfW1cUUkBuMBN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro air bnb eppo bro poduvinga?',
#   'Comment_Author': '@rsaakash5640',
#   'Comment_Published': '2024-06-18T12:42:39Z'},
#  {'Comment_Id': 'UgzTEIcP2rfsJorcwjB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro airbnb',
#   'Comment_Author': '@TamilMani-xk8jp',
#   'Comment_Published': '2024-06-07T05:12:38Z'},
#  {'Comment_Id': 'Ugy1bGTLoqkMF_kyB-t4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Thanks a lot bro.....🙂',
#   'Comment_Author': '@ramyamahesh5321',
#   'Comment_Published': '2024-06-03T09:15:30Z'},
#  {'Comment_Id': 'UgyOHEVSVuYq-uLl53B4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Anna unga final project guvi la enna naa????',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-28T13:48:53Z'},
#  {'Comment_Id': 'UgzqTpj2b6UQTSC_5Ip4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'anna neenga final project finish pannigala,pannigana link pls send pannugaa',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-25T13:52:23Z'},
#  {'Comment_Id': 'UgyiHC2UD2Mkg6cybcx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Start Airbnb bro 😢',
#   'Comment_Author': '@mounisht9775',
#   'Comment_Published': '2024-05-05T18:30:30Z'},
#  {'Comment_Id': 'Ugw4lvgUvapsdhvoaYt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project  start panungaa',
#   'Comment_Author': '@umaiyaumaiya9397',
#   'Comment_Published': '2024-05-02T11:00:07Z'},
#  {'Comment_Id': 'Ugw_g2KBjwUBjjz5ezx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-23T17:04:25Z'},
#  {'Comment_Id': 'UgxT1RzfpT4e9Qg5oZt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro can you give airbnb dataset csv link ?',
#   'Comment_Author': '@sgigadsgigad4019',
#   'Comment_Published': '2024-04-22T14:06:10Z'},
#  {'Comment_Id': 'UgwChSBzrOnb46BiNjN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro please start with next project airbnb bro please',
#   'Comment_Author': '@chopravalarmathi4588',
#   'Comment_Published': '2024-04-19T15:42:54Z'},
#  {'Comment_Id': 'UgyxITJFxOHcS-1SCTF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro please start pannuga',
# ...
#   'Comment_Author': '@srivanikothavadla8977',
#   'Comment_Published': '2024-03-29T16:30:52Z'},
#  {'Comment_Id': 'UgzYqK9WcnnK1cRFAy14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Videos avolo thana bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-03-28T04:45:16Z'},
#  {'Comment_Id': 'Ugxj2onJUdhrnQpWrj14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Brother kindly share me ur mail id',
#   'Comment_Author': '@v_see_you',
#   'Comment_Published': '2024-08-03T05:41:35Z'},
#  {'Comment_Id': 'UgzZQcwRiuR-CMjG_ox4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Give your insta id',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:37Z'},
#  {'Comment_Id': 'Ugzl87QynrTolzYDkWR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:12Z'},
#  {'Comment_Id': 'UgyeVVFeYK1ZUhFgqJR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro i need ah help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:00Z'},
#  {'Comment_Id': 'UgyChKONaDVL_PiOv-h4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please  bro airbnb start panunga bro',
#   'Comment_Author': '@murugalakshmiram5582',
#   'Comment_Published': '2024-06-22T05:18:48Z'},
#  {'Comment_Id': 'Ugxfh8FYdD-egdR1Yjt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next next project epa start panuvinga',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:32:47Z'},
#  {'Comment_Id': 'UgwCa_dJXul1OFYr2gV4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Inga elarume guvi student aa',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:27:52Z'},
#  {'Comment_Id': 'UgwMM5BfW1cUUkBuMBN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro air bnb eppo bro poduvinga?',
#   'Comment_Author': '@rsaakash5640',
#   'Comment_Published': '2024-06-18T12:42:39Z'},
#  {'Comment_Id': 'UgzTEIcP2rfsJorcwjB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro airbnb',
#   'Comment_Author': '@TamilMani-xk8jp',
#   'Comment_Published': '2024-06-07T05:12:38Z'},
#  {'Comment_Id': 'Ugy1bGTLoqkMF_kyB-t4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Thanks a lot bro.....🙂',
#   'Comment_Author': '@ramyamahesh5321',
#   'Comment_Published': '2024-06-03T09:15:30Z'},
#  {'Comment_Id': 'UgyOHEVSVuYq-uLl53B4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Anna unga final project guvi la enna naa????',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-28T13:48:53Z'},
#  {'Comment_Id': 'UgzqTpj2b6UQTSC_5Ip4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'anna neenga final project finish pannigala,pannigana link pls send pannugaa',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-25T13:52:23Z'},
#  {'Comment_Id': 'UgyiHC2UD2Mkg6cybcx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Start Airbnb bro 😢',
#   'Comment_Author': '@mounisht9775',
#   'Comment_Published': '2024-05-05T18:30:30Z'},
#  {'Comment_Id': 'Ugw4lvgUvapsdhvoaYt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project  start panungaa',
#   'Comment_Author': '@umaiyaumaiya9397',
#   'Comment_Published': '2024-05-02T11:00:07Z'},
#  {'Comment_Id': 'Ugw_g2KBjwUBjjz5ezx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-23T17:04:25Z'},
#  {'Comment_Id': 'UgxT1RzfpT4e9Qg5oZt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro can you give airbnb dataset csv link ?',
#   'Comment_Author': '@sgigadsgigad4019',
#   'Comment_Published': '2024-04-22T14:06:10Z'},
#  {'Comment_Id': 'UgwChSBzrOnb46BiNjN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro please start with next project airbnb bro please',
#   'Comment_Author': '@chopravalarmathi4588',
#   'Comment_Published': '2024-04-19T15:42:54Z'},
#  {'Comment_Id': 'UgyxITJFxOHcS-1SCTF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro please start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-16T13:45:34Z'},
#  {'Comment_Id': 'UgzRoFJgFDdLGzmd9mZ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro OCR PROJECT finished aa intha video la',
#   'Comment_Author': '@naufalmohamed',
#   'Comment_Published': '2024-04-15T11:02:21Z'},
#  {'Comment_Id': 'UgwdzonrSBxPf_cDFNF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro when starting Airbnb',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-12T09:50:57Z'},
#  {'Comment_Id': 'UgwwN0A7Q58ros1Yztt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project epo strat pannuvinga bro airbnb',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-11T04:42:30Z'},
#  {'Comment_Id': 'UgztB3jZp8Av1ie15eB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Aibhb project start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-09T06:43:32Z'},
#  {'Comment_Id': 'UgwzUBXsbQ_xfHALtRB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:28Z'},
#  {'Comment_Id': 'UgwM2MmksFypI0OqMD54AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro complete aa',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:14Z'},
#  {'Comment_Id': 'UgzpE7MKMAVj3ucDmYN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro next project epo upload panuveenga, upload panna work pani2 irukeengala, please rply bro',
#   'Comment_Author': '@qwertypad123',
#   'Comment_Published': '2024-04-03T14:21:20Z'},
#  {'Comment_Id': 'Ugyj-Hkr4j-_oL4_XTJ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Plss start Airbnb project bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-02T07:04:51Z'},
#  {'Comment_Id': 'UgyFCWPk2osM6PTykwp4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro you got a certificate from guvi',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-01T03:40:50Z'},
#  {'Comment_Id': 'Ugxu-94HubHyNwSocGF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Hi brother pls can teach us  airbnb project',
#   'Comment_Author': '@srivanikothavadla8977',
#   'Comment_Published': '2024-03-29T16:30:52Z'},
#  {'Comment_Id': 'UgzYqK9WcnnK1cRFAy14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Videos avolo thana bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-03-28T04:45:16Z'},
#  {'Comment_Id': 'Ugxj2onJUdhrnQpWrj14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Brother kindly share me ur mail id',
#   'Comment_Author': '@v_see_you',
#   'Comment_Published': '2024-08-03T05:41:35Z'},
#  {'Comment_Id': 'UgzZQcwRiuR-CMjG_ox4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Give your insta id',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:37Z'},
#  {'Comment_Id': 'Ugzl87QynrTolzYDkWR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:12Z'},
#  {'Comment_Id': 'UgyeVVFeYK1ZUhFgqJR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro i need ah help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:00Z'},
#  {'Comment_Id': 'UgyChKONaDVL_PiOv-h4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please  bro airbnb start panunga bro',
#   'Comment_Author': '@murugalakshmiram5582',
#   'Comment_Published': '2024-06-22T05:18:48Z'},
#  {'Comment_Id': 'Ugxfh8FYdD-egdR1Yjt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next next project epa start panuvinga',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:32:47Z'},
#  {'Comment_Id': 'UgwCa_dJXul1OFYr2gV4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Inga elarume guvi student aa',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:27:52Z'},
#  {'Comment_Id': 'UgwMM5BfW1cUUkBuMBN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro air bnb eppo bro poduvinga?',
#   'Comment_Author': '@rsaakash5640',
#   'Comment_Published': '2024-06-18T12:42:39Z'},
#  {'Comment_Id': 'UgzTEIcP2rfsJorcwjB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro airbnb',
#   'Comment_Author': '@TamilMani-xk8jp',
#   'Comment_Published': '2024-06-07T05:12:38Z'},
#  {'Comment_Id': 'Ugy1bGTLoqkMF_kyB-t4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Thanks a lot bro.....🙂',
#   'Comment_Author': '@ramyamahesh5321',
#   'Comment_Published': '2024-06-03T09:15:30Z'},
#  {'Comment_Id': 'UgyOHEVSVuYq-uLl53B4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Anna unga final project guvi la enna naa????',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-28T13:48:53Z'},
#  {'Comment_Id': 'UgzqTpj2b6UQTSC_5Ip4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'anna neenga final project finish pannigala,pannigana link pls send pannugaa',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-25T13:52:23Z'},
#  {'Comment_Id': 'UgyiHC2UD2Mkg6cybcx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Start Airbnb bro 😢',
#   'Comment_Author': '@mounisht9775',
#   'Comment_Published': '2024-05-05T18:30:30Z'},
#  {'Comment_Id': 'Ugw4lvgUvapsdhvoaYt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project  start panungaa',
#   'Comment_Author': '@umaiyaumaiya9397',
#   'Comment_Published': '2024-05-02T11:00:07Z'},
#  {'Comment_Id': 'Ugw_g2KBjwUBjjz5ezx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-23T17:04:25Z'},
#  {'Comment_Id': 'UgxT1RzfpT4e9Qg5oZt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro can you give airbnb dataset csv link ?',
#   'Comment_Author': '@sgigadsgigad4019',
#   'Comment_Published': '2024-04-22T14:06:10Z'},
#  {'Comment_Id': 'UgwChSBzrOnb46BiNjN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro please start with next project airbnb bro please',
#   'Comment_Author': '@chopravalarmathi4588',
#   'Comment_Published': '2024-04-19T15:42:54Z'},
#  {'Comment_Id': 'UgyxITJFxOHcS-1SCTF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro please start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-16T13:45:34Z'},
#  {'Comment_Id': 'UgzRoFJgFDdLGzmd9mZ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro OCR PROJECT finished aa intha video la',
#   'Comment_Author': '@naufalmohamed',
#   'Comment_Published': '2024-04-15T11:02:21Z'},
#  {'Comment_Id': 'UgwdzonrSBxPf_cDFNF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro when starting Airbnb',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-12T09:50:57Z'},
#  {'Comment_Id': 'UgwwN0A7Q58ros1Yztt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project epo strat pannuvinga bro airbnb',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-11T04:42:30Z'},
#  {'Comment_Id': 'UgztB3jZp8Av1ie15eB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Aibhb project start pannuga',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-09T06:43:32Z'},
#  {'Comment_Id': 'UgwzUBXsbQ_xfHALtRB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:28Z'},
#  {'Comment_Id': 'UgwM2MmksFypI0OqMD54AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro complete aa',
#   'Comment_Author': '@DatascientistH',
#   'Comment_Published': '2024-04-07T16:15:14Z'},
#  {'Comment_Id': 'UgzpE7MKMAVj3ucDmYN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro next project epo upload panuveenga, upload panna work pani2 irukeengala, please rply bro',
#   'Comment_Author': '@qwertypad123',
#   'Comment_Published': '2024-04-03T14:21:20Z'},
#  {'Comment_Id': 'Ugyj-Hkr4j-_oL4_XTJ4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Plss start Airbnb project bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-02T07:04:51Z'},
#  {'Comment_Id': 'UgyFCWPk2osM6PTykwp4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro you got a certificate from guvi',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-04-01T03:40:50Z'},
#  {'Comment_Id': 'Ugxu-94HubHyNwSocGF4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Hi brother pls can teach us  airbnb project',
#   'Comment_Author': '@srivanikothavadla8977',
#   'Comment_Published': '2024-03-29T16:30:52Z'},
#  {'Comment_Id': 'UgzYqK9WcnnK1cRFAy14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Videos avolo thana bro',
#   'Comment_Author': '@ramersaranya4177',
#   'Comment_Published': '2024-03-28T04:45:16Z'},
#  {'Comment_Id': 'Ugxj2onJUdhrnQpWrj14AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Brother kindly share me ur mail id',
#   'Comment_Author': '@v_see_you',
#   'Comment_Published': '2024-08-03T05:41:35Z'},
#  {'Comment_Id': 'UgzZQcwRiuR-CMjG_ox4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Give your insta id',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:37Z'},
#  {'Comment_Id': 'Ugzl87QynrTolzYDkWR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:12Z'},
#  {'Comment_Id': 'UgyeVVFeYK1ZUhFgqJR4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro i need ah help',
#   'Comment_Author': '@user-mi7wn3lu5d',
#   'Comment_Published': '2024-07-06T14:42:00Z'},
#  {'Comment_Id': 'UgyChKONaDVL_PiOv-h4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Please  bro airbnb start panunga bro',
#   'Comment_Author': '@murugalakshmiram5582',
#   'Comment_Published': '2024-06-22T05:18:48Z'},
#  {'Comment_Id': 'Ugxfh8FYdD-egdR1Yjt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next next project epa start panuvinga',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:32:47Z'},
#  {'Comment_Id': 'UgwCa_dJXul1OFYr2gV4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Inga elarume guvi student aa',
#   'Comment_Author': '@keerthinathan715',
#   'Comment_Published': '2024-06-21T17:27:52Z'},
#  {'Comment_Id': 'UgwMM5BfW1cUUkBuMBN4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro air bnb eppo bro poduvinga?',
#   'Comment_Author': '@rsaakash5640',
#   'Comment_Published': '2024-06-18T12:42:39Z'},
#  {'Comment_Id': 'UgzTEIcP2rfsJorcwjB4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'bro airbnb',
#   'Comment_Author': '@TamilMani-xk8jp',
#   'Comment_Published': '2024-06-07T05:12:38Z'},
#  {'Comment_Id': 'Ugy1bGTLoqkMF_kyB-t4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Thanks a lot bro.....🙂',
#   'Comment_Author': '@ramyamahesh5321',
#   'Comment_Published': '2024-06-03T09:15:30Z'},
#  {'Comment_Id': 'UgyOHEVSVuYq-uLl53B4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Anna unga final project guvi la enna naa????',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-28T13:48:53Z'},
#  {'Comment_Id': 'UgzqTpj2b6UQTSC_5Ip4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'anna neenga final project finish pannigala,pannigana link pls send pannugaa',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-05-25T13:52:23Z'},
#  {'Comment_Id': 'UgyiHC2UD2Mkg6cybcx4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Start Airbnb bro 😢',
#   'Comment_Author': '@mounisht9775',
#   'Comment_Published': '2024-05-05T18:30:30Z'},
#  {'Comment_Id': 'Ugw4lvgUvapsdhvoaYt4AaABAg',
#   'Video_Id': 'JdyZ-ek67bI',
#   'Comment_Text': 'Bro next project  start panungaa',
#   'Comment_Author': '@umaiyaumaiya9397',
#   'Comment_Published': '2024-05-02T11:00:07Z'},
#  ...]

# %%
len(comment_details)
# Out:
# 2059

# %%
# Get Playlist details


def get_playlist_details(channel_id):
    next_page_token=None
    All_data=[]
    while True:
        request=youtube.playlists().list(
            part='snippet,contentDetails',
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token
        )
        response=request.execute()

        for item in response['items']:
            data=dict(Playlist_Id=item['id'],
                    Title=item['snippet']['title'],
                    Channel_Id=item['snippet']['channelId'],
                    Channel_Name=item['snippet']['channelTitle'],
                    PublishedAt=item['snippet']['publishedAt'],
                    Video_Count=item['contentDetails']['itemCount'])
            All_data.append(data)
            
        next_page_token=response.get('nextPageToken')
        if next_page_token is None:
            break
    return All_data

# %%
playlist_details=get_playlist_details('UCuI5XcJYynHa5k_lqDzAgwQ')

# %%
playlist_details
# Out:
# [{'Playlist_Id': 'PLuo9105K6NLR0XRJweyZ1vZeqQFiJ-xv8',
#   'Title': 'BizCardX: Extracting Business Card Data with OCR',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Channel_Name': 'Data Science Tamil',
#   'PublishedAt': '2024-03-18T06:25:57Z',
#   'Video_Count': 10},
#  {'Playlist_Id': 'PLuo9105K6NLRozcPvyXG4fx3z2-cvXG3G',
#   'Title': 'PhonePe Pulse Data Visualization and Exploration',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Channel_Name': 'Data Science Tamil',
#   'PublishedAt': '2023-11-16T02:20:12Z',
#   'Video_Count': 41},
#  {'Playlist_Id': 'PLuo9105K6NLRe85dP13b0i57AkgyLWOFj',
#   'Title': 'YouTube Data Harvesting and Warehousing',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Channel_Name': 'Data Science Tamil',
#   'PublishedAt': '2023-10-17T20:13:20Z',
#   'Video_Count': 20}]

# %%
len(playlist_details)
# Out:
# 3

# %%
# Upload to MongoDB
client=pymongo.MongoClient("mongodb+srv://vinolarani2120:donbosco@cluster0.oaumhyu.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

# %%
all_channels=[]
db=client["Youtube_data"]
coll1=db["channel_details"]
for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
    all_channels.append(ch_data["channel_information"]["Channel_Name"])

# %%
all_channels
# Out:
# ['K Talk Movies', 'Data Science Tamil']

# %%
single_channel_detail=[]
db=client["Youtube_data"]
coll1=db["channel_details"]
for ch_data in coll1.find({"channel_information.Channel_Name":"K Talk Movies"},{"_id":0}):
    single_channel_detail.append(ch_data["channel_information"])

df_single_channel_detail=pd.DataFrame(single_channel_detail)

# %%
df_single_channel_detail
# Out:
#     Channel_Name                Channel_Id Subscribers     Views Total_Videos  \
# 0  K Talk Movies  UCydCXKxPQnCZi-jW9PtAFaQ      139000  36775713          223
#
#                                  Channel_Description               Playlist_Id
# 0  \n\n\n\nK-Talk Movies\n\nK-talk Movies youtube...  UUydCXKxPQnCZi-jW9PtAFaQ

# %%
single_playlist_details=[]
db=client["Youtube_data"]
coll1=db["channel_details"]
for ch_data in coll1.find({"channel_information.Channel_Name":"K Talk Movies"},{"_id":0,"playlist_information":1}):
     single_playlist_details.append(ch_data["playlist_information"])

df = pd.DataFrame(single_playlist_details[0])

# %%
df
# Out:
#                           Playlist_Id                     Title  \
# 0  PLW_ZlqUrbDgh-95de36CRJMmry8FUr74m          Hollywood movies
# 1  PLW_ZlqUrbDgifDLfh2Marj8r04Vz5BFpW  japanese movies in tamil
# 2  PLW_ZlqUrbDghyI44EBpjUtJrzZ7hOe7ey      Thai movies in Tamil
# 3  PLW_ZlqUrbDgiTVRnaxTcWjkSDMkenji1Z   Chinese movies in tamil
# 4  PLW_ZlqUrbDghaqVCz1H4zQWoVHXSlQCcf   fantasy movies in tamil
# 5  PLW_ZlqUrbDgiDP7jnHgO2hRN7qcGLAGWW    korean movies in tamil
# 6  PLW_ZlqUrbDggNIefcAicL4dKeM56BRF0E           Monster  ❤Human
# 7  PLW_ZlqUrbDgjLoV8kBYDODqTh0I-LCiPr   Famous chef ❤crazy girl
#
#                  Channel_Id   Channel_Name           PublishedAt  Video_Count
# 0  UCydCXKxPQnCZi-jW9PtAFaQ  K Talk Movies  2023-04-18T19:38:42Z            1
# 1  UCydCXKxPQnCZi-jW9PtAFaQ  K Talk Movies  2022-12-15T09:39:08Z            6
# 2  UCydCXKxPQnCZi-jW9PtAFaQ  K Talk Movies  2022-12-14T11:57:13Z           19
# 3  UCydCXKxPQnCZi-jW9PtAFaQ  K Talk Movies  2022-12-05T19:09:04Z          190
# 4  UCydCXKxPQnCZi-jW9PtAFaQ  K Talk Movies  2022-08-31T05:52:46Z            1
# 5  UCydCXKxPQnCZi-jW9PtAFaQ  K Talk Movies  2022-08-17T11:50:58Z           21
# 6  UCydCXKxPQnCZi-jW9PtAFaQ  K Talk Movies  2022-07-11T08:09:26Z           12
# 7  UCydCXKxPQnCZi-jW9PtAFaQ  K Talk Movies  2022-06-21T12:44:09Z            1

# %%
def channel_details(channel_id):
    ch_details=get_channel_info(channel_id)
    pl_details=get_playlist_details(channel_id)
    vi_ids=get_videos_ids(channel_id)
    vi_details=get_video_info(vi_ids)
    com_details=get_comment_info(vi_ids)

    coll1=db["channel_details"]
    coll1.insert_one({"channel_information":ch_details,"playlist_information":pl_details,
                      "video_information":vi_details,"comment_information":com_details})
    return "upload completed succefully"

# %%
insert=channel_details("UCuI5XcJYynHa5k_lqDzAgwQ")

# %%
insert
# Out:
# 'upload completed succefully'

# %%
# Table Creation for Channel, Playlists, Commends

def channels_table(channel_name_s):
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="donbosco",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

    

    
    create_query='''create table if not exists channels(Channel_Name varchar(100),
                                                        Channel_Id varchar(80) primary key,
                                                        Subscribers bigint,
                                                        Views bigint,
                                                        Total_Videos int,
                                                        Channel_Description text,
                                                        Playlist_Id varchar(80))'''
    cursor.execute(create_query)
    mydb.commit()

    

    single_channel_detail=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({"channel_information.Channel_Name":"K Talk Movies"},{"_id":0}):
        single_channel_detail.append(ch_data["channel_information"])

    df_single_channel_detail=pd.DataFrame(single_channel_detail)
    

    for index,row in df_single_channel_detail.iterrows():
    
        insert_query=''' insert into channels(Channel_Name,
                                                Channel_Id,
                                                Subscribers,
                                                Views,
                                                Total_Videos,
                                                Channel_Description,
                                                Playlist_Id
                                            )
                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['Channel_Name'],
                row['Channel_Id'],
                row['Subscribers'],
                row['Views'],
                row['Total_Videos'],
                row['Channel_Description'],
                row['Playlist_Id'])
        
        
        try:

            cursor.execute(insert_query, values)
            mydb.commit()
        except:
            news= f"Your Provided Channel Name {channel_name_s} is Already Exists"
        
            return news

# %%
channels_table("Data Science Tamil")
# Out:
# 'Your Provided Channel Name Data Science Tamil is Already Exists'

# %%
def playlist_table(channel_name_s):
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="donbosco",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()


    create_query='''create table if not exists playlists(Playlist_Id  varchar(100) primary key,
                                                        Title varchar(100),
                                                        Channel_Id varchar(100),
                                                        Channel_Name varchar(100),
                                                        PublishedAt timestamp,
                                                        Video_Count int
                                                        )'''
    cursor.execute(create_query)
    mydb.commit()



    single_playlist_details=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({"channel_information.Channel_Name":"K Talk Movies"},{"_id":0,"playlist_information":1}):
        single_playlist_details.append(ch_data["playlist_information"])

    df = pd.DataFrame(single_playlist_details[0])

    for index,row in df.iterrows():
            
        insert_query=''' insert into playlists(Playlist_Id,                                            
                                                Title,
                                                Channel_Id,
                                                Channel_Name,
                                                PublishedAt,
                                                Video_Count
                                            )

                                            values(%s,%s,%s,%s,%s,%s)'''
        values=(row['Playlist_Id'],
                row['Title'],
                row['Channel_Id'],
                row['Channel_Name'],
                row['PublishedAt'],
                row['Video_Count']
                )
        

        cursor.execute(insert_query,values)
        mydb.commit()

# %%
playlist_table("Data Science Tamil")
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 playlist_table("Data Science Tamil")
#
# Cell In[36], line 50, in playlist_table(channel_name_s)
#      32 insert_query=''' insert into playlists(Playlist_Id,
#      33                                         Title,
#      34                                         Channel_Id,
#    (...)
#      39
#      40                                     values(%s,%s,%s,%s,%s,%s)'''
#      41 values=(row['Playlist_Id'],
#      42         row['Title'],
#      43         row['Channel_Id'],
#    (...)
#      46         row['Video_Count']
#      47         )
# ---> 50 cursor.execute(insert_query,values)
#      51 mydb.commit()
#
# UniqueViolation: duplicate key value violates unique constraint "playlists_pkey"
# DETAIL:  Key (playlist_id)=(PLW_ZlqUrbDgh-95de36CRJMmry8FUr74m) already exists.

# %%
single_video_details=[]
db=client["Youtube_data"]
coll1=db["channel_details"]
for ch_data in coll1.find({"video_information.Channel_Name":"Data Science Tamil"},{"_id":0,"video_information":1}):
    single_video_details.append(ch_data["video_information"])

df_single_video_details=pd.DataFrame(single_video_details[0])

# %%
def videos_table(channel_name_s):
    mydb=psycopg2.connect(host="localhost",
                    user="postgres",
                    password="donbosco",
                    database="youtube_data",
                    port="5432")
    cursor=mydb.cursor()


    create_query='''create table if not exists videos(Channel_Name varchar(100),
                                            Channel_Id varchar(100),
                                            Video_Id varchar(30),
                                            Title varchar(150),
                                            Tags text,
                                            Thumbnail varchar(200),
                                            Description text,
                                            Published_Date timestamp,
                                            Duration interval,
                                            Views bigint,
                                            Likes bigint,
                                            Comments int,
                                            Favorite_Count int,
                                            Definition varchar(10),
                                            Caption_Status varchar(50)
                                            )'''
    cursor.execute(create_query)
    mydb.commit()

    single_video_details=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({"video_information.Channel_Name":"Data Science Tamil"},{"_id":0,"video_information":1}):
        single_video_details.append(ch_data["video_information"])

    df_single_video_details=pd.DataFrame(single_video_details[0])

    for index,row in df_single_video_details.iterrows():
        insert_query=''' insert into videos(Channel_Name,
                                        Channel_Id,
                                        Video_Id,
                                        Title,
                                        Tags,
                                        Thumbnail,
                                        Description,
                                        Published_Date,
                                        Duration,
                                        Views,
                                        Likes,
                                        Comments,
                                        Favorite_Count,
                                        Definition,
                                        Caption_Status 
                                        )
                                        values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''

        values=(row['Channel_Name'],
                row['Channel_Id'],
                row['Video_Id'],
                row['Title'],
                row['Tags'],
                row['Thumbnail'],
                row['Description'],
                row['Published_Date'],
                row['Duration'],
                row['Views'],
                row['Likes'],
                row['Comments'],
                row['Favorite_Count'],
                row['Definition'],
                row['Caption_Status'])

        cursor.execute(insert_query, values)
        mydb.commit()

# %%
videos_table("Data Science Tamil")

# %%
single_comments_details=[]
db=client["Youtube_data"]
coll1=db["channel_details"]
for ch_data in coll1.find({"channel_information.Channel_Name":"Data Science Tamil"},{"_id":0}):
    single_comments_details.append(ch_data["comment_information"])

df_single_comments_details=pd.DataFrame(single_comments_details[0])

# %%
df_single_comments_details
# Out:
#                       Comment_Id     Video_Id  \
# 0     Ugxj2onJUdhrnQpWrj14AaABAg  JdyZ-ek67bI
# 1     UgzZQcwRiuR-CMjG_ox4AaABAg  JdyZ-ek67bI
# 2     Ugzl87QynrTolzYDkWR4AaABAg  JdyZ-ek67bI
# 3     UgyeVVFeYK1ZUhFgqJR4AaABAg  JdyZ-ek67bI
# 4     UgyChKONaDVL_PiOv-h4AaABAg  JdyZ-ek67bI
# ...                          ...          ...
# 2054  Ugykd0Y6oD3wiJXG5dx4AaABAg  Bqgjq6NGL4c
# 2055  Ugy0uAUpYBZsOp5QcV94AaABAg  Bqgjq6NGL4c
# 2056  UgwlmWJWfA6EsiF0Wsh4AaABAg  Bqgjq6NGL4c
# 2057  UgwP-D6UKKoPrJn6Gv54AaABAg  Bqgjq6NGL4c
# 2058  UgwSp7JRWZuE2R2vS_Z4AaABAg  Bqgjq6NGL4c
#
#                                            Comment_Text  \
# 0                    Brother kindly share me ur mail id
# 1                                    Give your insta id
# 2                                           Please help
# 3                                    Bro i need ah help
# 4                  Please  bro airbnb start panunga bro
# ...                                                 ...
# 2054                     Waiting for upcoming video sir
# 2055  Bro bar chart and map are not visible in strea...
# 2056  in path 5 and path 6 i am getting keyerror wit...
# 2057  bro, how many videos are more able to complete...
# 2058                                  Thank you so much
#
#                 Comment_Author     Comment_Published
# 0                   @v_see_you  2024-08-03T05:41:35Z
# 1             @user-mi7wn3lu5d  2024-07-06T14:42:37Z
# 2             @user-mi7wn3lu5d  2024-07-06T14:42:12Z
# 3             @user-mi7wn3lu5d  2024-07-06T14:42:00Z
# 4        @murugalakshmiram5582  2024-06-22T05:18:48Z
# ...                        ...                   ...
# 2054              @mperumal726  2023-11-27T05:14:26Z
# 2055             @arunbala7127  2023-11-26T08:44:26Z
# 2056           @sakthiviji2023  2023-11-25T12:14:05Z
# 2057        @naveenkumar-rb8rm  2023-11-23T13:44:29Z
# 2058  @renugadevichakkarai6111  2023-11-23T11:37:47Z
#
# [2059 rows x 5 columns]

# %%
def comments_table(channel_name_s):
        mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="donbosco",
                        database="youtube_data",
                        port="5432")
        cursor=mydb.cursor()

        
        create_query='''create table if not exists comments(Comment_Id varchar(100) primary key,
                                                                Video_Id varchar(50),
                                                                Comment_Text text,
                                                                Comment_Author varchar(150),
                                                                Comment_Published timestamp
                                                                )'''
        cursor.execute(create_query)
        mydb.commit()

        single_comments_details=[]
        db=client["Youtube_data"]
        coll1=db["channel_details"]
        for ch_data in coll1.find({"channel_information.Channel_Name":channel_name_s},{"_id":0,"comment_information":1}):
            single_comments_details.append(ch_data["comment_information"])

        df_single_comments_details=pd.DataFrame(single_comments_details[0])


        for index,row in df_single_comments_details.iterrows():
                
                insert_query='''insert into comments(Comment_Id,
                                                Video_Id,
                                                Comment_Text,
                                                Comment_Author,
                                                Comment_Published
                                                )
                                                values(%s,%s,%s,%s,%s)'''
                
                values=(row['Comment_Id'],
                        row['Video_Id'],
                        row['Comment_Text'],
                        row['Comment_Author'],
                        row['Comment_Published']
                        )
                
                cursor.execute(insert_query,values)
                mydb.commit()

# %%
comments_table("Data Science Tamil")
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 comments_table("Data Science Tamil")
#
# Cell In[43], line 45, in comments_table(channel_name_s)
#      30 insert_query='''insert into comments(Comment_Id,
#      31                                 Video_Id,
#      32                                 Comment_Text,
#    (...)
#      35                                 )
#      36                                 values(%s,%s,%s,%s,%s)'''
#      38 values=(row['Comment_Id'],
#      39         row['Video_Id'],
#      40         row['Comment_Text'],
#      41         row['Comment_Author'],
#      42         row['Comment_Published']
#      43         )
# ---> 45 cursor.execute(insert_query,values)
#      46 mydb.commit()
#
# UniqueViolation: duplicate key value violates unique constraint "comments_pkey"
# DETAIL:  Key (comment_id)=(Ugxj2onJUdhrnQpWrj14AaABAg) already exists.

# %%
def tables(channel_name_s):
    news=channels_table(channel_name_s)
    if news:
        print(news)
    else:
        channels_table(channel_name_s)
        playlist_table(channel_name_s)
        videos_table(channel_name_s)
        comments_table(channel_name_s)

    return "Tables Created Successfully"

# %%
Tables=tables("Data Science Tamil")
# Out:
# Your Provided Channel Name Data Science Tamil is Already Exists

# %%
Tables
# Out:
# 'Tables Created Successfully'

# %%
def show_channels_tables():
    ch_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])

    df=st.dataframe(ch_list)    

    return df

# %%
def show_playlists_table():
    pl_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
    df1=st.dataframe(pl_list)

    return df1

# %%
def show_videos_table():
    vi_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
    df2=st.dataframe(vi_list)

    return df2

# %%
def show_commends_table():
        com_list=[]
        db=client["Youtube_data"]
        coll1=db["channel_details"]
        for com_data in coll1.find({},{"_id":0,"comment_information":1}):
                for i in range(len(com_data["comment_information"])):
                        com_list.append(com_data["comment_information"][i])
                df3=st.dataframe(com_list)

                return df3

# %%
# streamlit part

with st.sidebar:
    st.title(":red[YOUTUBE DATA HARVERSTING AND WAREHOUSING]")
    st.header("Skill Take Away")
    st.caption("Python Scripting")
    st.caption("Data collection")
    st.caption("MongoDB")
    st.caption("API Integration")
    st.caption("Data Management using MongoDB and SQL")

channel_id=st.text_input("Enter the Channel ID")

if st.button("collect and store data"):
    ch_ids=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_ids.append(ch_data["channel_information"]["Channel_Id"])

    if channel_id in ch_ids:
        st.success("Channel Details of the given channel id already exists")

    else:
        insert=channel_details(channel_id)
        st.success(insert)

if st.button("Migrate to sql"):
    Table=tables()
    st.success(Table)

show_table=st.radio("SELECT THE TABLE FOR VIEW",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))
if show_table=="CHANNELS":
    show_channels_tables()

elif show_table=="PLAYLISTS":
    show_playlists_table()

elif show_table=="VIDEOS":
    show_videos_table()

elif show_table=="COMMENTS":
    show_commends_table()
# Out:
# 2024-08-10 12:28:48.776
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\LENOVO\Desktop\v\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-08-10 12:28:48.776 Session state does not function when running a script without `streamlit run`

# %%
#SQL Connection

mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="donbosco",
                        database="youtube_data",
                        port="5432")
cursor=mydb.cursor()

question=st.selectbox("Select your question",("1. All the videos and the channel name",
                                              "2. Channels with most number of videos ",
                                              "3. 10 most viewed videos ",
                                              "4. Comments in each videos",
                                              "5. Videos with highest Likes",
                                              "6. Likes of all videos",
                                              "7. Views of each channel",
                                              "8. Videos Published in the year of 2024",
                                              "9. Average duration of all videos in each channel",
                                              "10. Videos with highest number of comments"))

if question=="1. All the videos and the channel name":
    query1=''' select title as videos,channel_name as channelname from videos'''
    cursor.execute(query1)
    mydb.commit()
    t1=cursor.fetchall()
    df=pd.DataFrame(t1, columns=["video title","channel name"])
    st.write(df)

elif question=="2. Channels with most number of videos ":
    query2=''' select channel_name as channelname,total_videos as no_videos from channels
                order by Total_Videos desc'''
    cursor.execute(query2)
    mydb.commit()
    t2=cursor.fetchall()
    df2=pd.DataFrame(t2,columns=["channelname","no_videos"])
    st.write(df2)

elif question=="3. 10 most viewed videos ":
    query3='''select views as views,channel_name as channelname,title as videotitle from videos
                where views is not null order by views desc limit 10'''
    cursor.execute(query3)
    mydb.commit()
    t3=cursor.fetchall()
    df3=pd.DataFrame(t3,columns=["views","channel name","videotitle"])
    st.write(df3)

elif question=="4. Comments in each videos":
    query4='''select comments as no_comments,title as videotitle from videos where comments is not null'''
    cursor.execute(query4)
    mydb.commit()
    t4=cursor.fetchall()
    df4=pd.DataFrame(t4,columns=[" no  of comments ","videotitle"])
    st.write(df4)

elif question=="5. Videos with highest Likes":
    query5='''select title as videotitle,channel_name as channelname,like as likecount 
                from videos where likes is not null order by likes desc'''
    cursor.execute(query5)
    mydb.commit()
    t5=cursor.fetchall()
    df5=pd.DataFrame(t5,columns=["videotitle","channelname","likecount"])
    st.write(df5)

elif question=="6. Likes of all videos":
    query6='''select likes as likecount,title as videotitle from videos'''
    cursor.execute(query6)
    mydb.commit()
    t6=cursor.fetchall()
    df6=pd.DataFrame(t6,columns=["likecount","videotitle"])
    st.write(df6)

elif question=="7.Views of each channel":
    query7='''select channel_name as channelname, views as totalviews from channels'''
    cursor.execute(query7)
    mydb.commit()
    t7=cursor.fetchall()
    df7=pd.DataFrame(t7,columns=["channelname","totalviews"])
    st.write(df7)

elif question=="8. Videos Published in the year of 2024":
    query8='''select title as video_title, published_date as videorelease, channel_name as channelname from videos
                where extract(year from published_date)=2024'''
    cursor.execute(query8)
    mydb.commit()
    t8=cursor.fetchall()
    df8=pd.DataFrame(t8,columns=["video_title","published_date","channelname"])
    st.write(df8)

elif question=="9. Average duration of all videos in each channel":
    query9='''select channel_name as channelname, AVG(duration) as averageduration from videos group by channel_name'''
    cursor.execute(query9)
    mydb.commit()
    t9=cursor.fetchall()
    df9=pd.DataFrame(t9,columns=["channelname","averageduration"])
    df9

    T9=[]
    for index,row in df9.iterrows():
        channel_title=row["channelname"]
        average_duration=row["averageduration"]
        average_duration_str=str(average_duration)
        T9.append(dict(channeltitle=channel_title,averageduration=average_duration_str))

    df1=pd.DataFrame(T9)
    st.write(df1)

elif question=="10. Videos with highest number of comments":
    query10='''select title as videotitle,channel_name as channelname,comments as comments from videos where comments is 
            not null order by comments desc'''
    cursor.execute(query10)
    mydb.commit()
    t10=cursor.fetchall()
    df10=pd.DataFrame(t10,columns=["videotitle","channelname","comments"])
    st.write(df10)

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="donbosco",
                        database="youtube_data",
                        port="5432")
cursor=mydb.cursor()


#if question=="1. All the videos and the channel name":
query1=''' select title as videos,channel_name as channelname from videos'''
cursor.execute(query1)
mydb.commit()
t1=cursor.fetchall()
df=pd.DataFrame(t1, columns=["video title","channel name"])
#st.write(df)

df
# Out:
#                                            video title        channel name
# 0    Delete the Data from Table |BizCardX:Extractin...  Data Science Tamil
# 1    Delete the Data from Table |BizCardX:Extractin...  Data Science Tamil
# 2    Delete the Data from Table |BizCardX:Extractin...  Data Science Tamil
# 3    Delete the Data from Table |BizCardX:Extractin...  Data Science Tamil
# 4    Delete the Data from Table |BizCardX:Extractin...  Data Science Tamil
# ..                                                 ...                 ...
# 141  PhonePe Pulse Data Visualization and Explorati...  Data Science Tamil
# 142  PhonePe Pulse Data Visualization and Explorati...  Data Science Tamil
# 143  PhonePe Pulse Data Visualization and Explorati...  Data Science Tamil
# 144  PhonePe Pulse Data Visualization and Explorati...  Data Science Tamil
# 145  PhonePe Pulse Data Visualization and Explorati...  Data Science Tamil
#
# [146 rows x 2 columns]
